# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LeakyReLU, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam

# %%
file_path = 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv'
df = pd.read_csv(file_path)

print("Columns in the dataset:", df.columns)


categorical_columns = df.select_dtypes(include=['object']).columns
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le


columns_to_drop = ["Flow ID", " Source IP", " Source Port", " Destination IP", " Destination Port", " Protocol", " Timestamp", "Fwd Header Length", "Bwd Header Length", "Fwd Packet Length Mean", "Bwd Packet Length Mean", "Bwd Packet Length Std", "Fwd Packets/s", "Bwd Packets/s", "Fwd IAT Mean", "Fwd IAT Std", "Bwd IAT Mean", "Bwd IAT Std", "Fwd PSH Flags", "Bwd PSH Flags", "Fwd URG Flags", "Bwd URG Flags", "Fwd Packets/s", "Bwd Packets/s", "Bwd Packet Length Max", "Bwd Packet Length Std", "Fwd Avg Bytes/Bulk", "Fwd Avg Packets/Bulk", "Fwd Avg Bulk Rate", "Bwd Avg Bytes/Bulk", "Bwd Avg Packets/Bulk", "Bwd Avg Bulk Rate", "Subflow Fwd Packets", "Subflow Bwd Packets", "Init_Win_bytes_forward", "Init_Win_bytes_backward", "act_data_pkt_fwd", "min_seg_size_forward"]
df.drop(columns_to_drop, axis=1, inplace=True, errors='ignore')


df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

print("Unique values in ' Label' column:", df[' Label'].unique())


benign_data = df[df[' Label'] == 0]  
ddos_data = df[df[' Label'] == 1]    

print(f"Number of BENIGN samples: {len(benign_data)}")
print(f"Number of DDoS samples: {len(ddos_data)}")

if len(benign_data) == 0 or len(ddos_data) == 0:
    raise ValueError("No samples found for BENIGN or DDoS labels. Check the dataset and labels.")


scaler = MinMaxScaler()
benign_data_scaled = scaler.fit_transform(benign_data)
ddos_data_scaled = scaler.fit_transform(ddos_data)

latent_dim = 100
# Out:
# Columns in the dataset: Index(['Flow ID', ' Source IP', ' Source Port', ' Destination IP',
#        ' Destination Port', ' Protocol', ' Timestamp', ' Flow Duration',
#        ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
#        ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length',
#        ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',
#        'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count',
#        ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count',
#        ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio',
#        ' Average Packet Size', ' Avg Fwd Segment Size',
#        ' Avg Bwd Segment Size', ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk',
#        ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk',
#        ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets',
#        ' Subflow Fwd Bytes', ' Subflow Bwd Packets', ' Subflow Bwd Bytes',
#        'Init_Win_bytes_forward', ' Init_Win_bytes_backward',
#        ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean',
#        ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std',
#        ' Idle Max', ' Idle Min', ' Label'],
#       dtype='object')
# Unique values in ' Label' column: [0 1]
# Number of BENIGN samples: 97686
# Number of DDoS samples: 128025

# %%
def build_generator():
    model = Sequential()
    model.add(Dense(128, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(df.shape[1], activation='tanh'))
    return model

# %%
def build_discriminator():
    model = Sequential()
    model.add(Dense(512, input_dim=df.shape[1]))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
def train_gan(data, epochs, batch_size=64, save_interval=100, category="BENIGN"):
    half_batch = int(batch_size / 2)
    adam = Adam(learning_rate=0.0002, beta_1=0.5)

    generator = build_generator()
    discriminator = build_discriminator()
    discriminator.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

    z = Input(shape=(latent_dim,))
    generated_data = generator(z)
    discriminator.trainable = False
    validity = discriminator(generated_data)
    combined = Model(z, validity)
    combined.compile(loss='binary_crossentropy', optimizer=adam)

    min_loss_improvement = 1e-4  # Threshold for loss improvement
    previous_loss = np.inf

    for epoch in range(epochs):
        # Sample real and fake data
        idx = np.random.randint(0, data.shape[0], half_batch)
        real_data = data[idx]
        noise = np.random.normal(0, 1, (half_batch, latent_dim))
        generated_data = generator.predict(noise)

        # Train discriminator on real and fake data
        d_loss_real = discriminator.train_on_batch(real_data, np.ones((half_batch, 1)))
        d_loss_fake = discriminator.train_on_batch(generated_data, np.zeros((half_batch, 1)))
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train generator via combined model
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        valid_y = np.array([1] * batch_size)
        g_loss = combined.train_on_batch(noise, valid_y)

        # Printing the progress
        print(f"{category} Epoch {epoch + 1}/{epochs} [D loss: {d_loss[0]}, acc.: {100 * d_loss[1]}] [G loss: {g_loss}]")

        # Extracting the first element (loss) from g_loss and comparing it
        if isinstance(g_loss, list):
            g_loss_value = g_loss[0]  # Extract loss value from list
        else:
            g_loss_value = g_loss

        # Check for insignificant loss improvement
        if abs(previous_loss - g_loss_value) < min_loss_improvement:
            print(f"Training stopped early due to insignificant loss improvement at epoch {epoch + 1}")
            break
        previous_loss = g_loss_value

        # Saving the model at specified intervals
        if (epoch + 1) % save_interval == 0:
            save_generated_data(generator, epoch + 1, category)
            save_model(generator, f"{category}_generator_epoch_{epoch + 1}.h5")

# %%
def save_generated_data(generator, epoch, category):
    try:
        noise = np.random.normal(0, 1, (1000, latent_dim))
        generated_data = generator.predict(noise)
        
        generated_data = scaler.inverse_transform(generated_data)
        
        print(f"Generated data shape: {generated_data.shape}")
        print(f"First row of generated data: {generated_data[0]}")
        
        df_generated = pd.DataFrame(generated_data, columns=df.columns)

        for col in categorical_columns:
            if col in df_generated.columns:
                df_generated[col] = label_encoders[col].inverse_transform(df_generated[col].astype(int))
        
        for col in columns_to_drop:
            if col not in df_generated.columns:
                df_generated[col] = ""

        df_generated = df_generated[columns_to_drop + df.columns.tolist()]
        
        file_name = f'generated_{category}_packets_epoch_{epoch}.csv'
        df_generated.to_csv(file_name, index=False)
        print(f"Generated {category} data saved as {file_name}")
    
    except Exception as e:
        print(f"Error while saving generated data: {e}")

# %%
def save_model(generator, filename):
    generator.save(filename)
    print(f"Model saved as {filename}")

train_gan(benign_data_scaled, epochs=200, batch_size=64, save_interval=200, category="BENIGN")
train_gan(ddos_data_scaled, epochs=200, batch_size=64, save_interval=200, category="DDoS")
# Out:
# c:\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Python311\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# c:\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# BENIGN Epoch 1/200 [D loss: 0.694170355796814, acc.: 75.0] [G loss: [array(0.71007496, dtype=float32), array(0.71007496, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 2/200 [D loss: 0.7031886577606201, acc.: 58.33333730697632] [G loss: [array(0.70801497, dtype=float32), array(0.70801497, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 3/200 [D loss: 0.7050981521606445, acc.: 55.000001192092896] [G loss: [array(0.7087981, dtype=float32), array(0.7087981, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 4/200 [D loss: 0.7064563035964966, acc.: 53.57142686843872] [G loss: [array(0.7091882, dtype=float32), array(0.7091882, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 5/200 [D loss: 0.7082676291465759, acc.: 52.77777910232544] [G loss: [array(0.7113284, dtype=float32), array(0.7113284, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 6/200 [D loss: 0.7100783586502075, acc.: 52.272725105285645] [G loss: [array(0.7125241, dtype=float32), array(0.7125241, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# BENIGN Epoch 7/200 [D loss: 0.7115463614463806, acc.: 51.923078298568726] [G loss: [array(0.71370554, dtype=float32), array(0.71370554, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 8/200 [D loss: 0.7129485607147217, acc.: 51.66666507720947] [G loss: [array(0.7151606, dtype=float32), array(0.7151606, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# BENIGN Epoch 9/200 [D loss: 0.7145746946334839, acc.: 51.47058963775635] [G loss: [array(0.71656805, dtype=float32), array(0.71656805, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 10/200 [D loss: 0.7162279486656189, acc.: 51.31579041481018] [G loss: [array(0.718236, dtype=float32), array(0.718236, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 11/200 [D loss: 0.7182493805885315, acc.: 51.1904776096344] [G loss: [array(0.72033685, dtype=float32), array(0.72033685, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 12/200 [D loss: 0.7202158570289612, acc.: 51.0869562625885] [G loss: [array(0.72219294, dtype=float32), array(0.72219294, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 13/200 [D loss: 0.7218611240386963, acc.: 50.999999046325684] [G loss: [array(0.72347766, dtype=float32), array(0.72347766, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 14/200 [D loss: 0.7231854796409607, acc.: 50.92592239379883] [G loss: [array(0.72489995, dtype=float32), array(0.72489995, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 15/200 [D loss: 0.7247840166091919, acc.: 50.86206793785095] [G loss: [array(0.7264027, dtype=float32), array(0.7264027, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# BENIGN Epoch 16/200 [D loss: 0.7262639999389648, acc.: 50.806450843811035] [G loss: [array(0.72785646, dtype=float32), array(0.72785646, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# BENIGN Epoch 17/200 [D loss: 0.7279015779495239, acc.: 50.757575035095215] [G loss: [array(0.7295439, dtype=float32), array(0.7295439, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 18/200 [D loss: 0.7293798923492432, acc.: 50.714290142059326] [G loss: [array(0.73086125, dtype=float32), array(0.73086125, dtype=float32), array(0.5, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 19/200 [D loss: 0.7305055856704712, acc.: 50.75790882110596] [G loss: [array(0.731656, dtype=float32), array(0.731656, dtype=float32), array(0.50164473, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# BENIGN Epoch 20/200 [D loss: 0.7313044667243958, acc.: 50.79927444458008] [G loss: [array(0.73248225, dtype=float32), array(0.73248225, dtype=float32), array(0.5015625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 21/200 [D loss: 0.7322158813476562, acc.: 50.76037645339966] [G loss: [array(0.7334394, dtype=float32), array(0.7334394, dtype=float32), array(0.5014881, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# BENIGN Epoch 22/200 [D loss: 0.7333575487136841, acc.: 50.72509050369263] [G loss: [array(0.73466486, dtype=float32), array(0.73466486, dtype=float32), array(0.50142044, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 23/200 [D loss: 0.7344237565994263, acc.: 50.692933797836304] [G loss: [array(0.73564565, dtype=float32), array(0.73564565, dtype=float32), array(0.5013587, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 24/200 [D loss: 0.7354220747947693, acc.: 50.66350698471069] [G loss: [array(0.73670274, dtype=float32), array(0.73670274, dtype=float32), array(0.50130206, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 25/200 [D loss: 0.7364565134048462, acc.: 50.63648223876953] [G loss: [array(0.7375774, dtype=float32), array(0.7375774, dtype=float32), array(0.50125, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 26/200 [D loss: 0.7373852729797363, acc.: 50.61156749725342] [G loss: [array(0.73850757, dtype=float32), array(0.73850757, dtype=float32), array(0.5012019, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 27/200 [D loss: 0.7382726073265076, acc.: 50.58853030204773] [G loss: [array(0.7393397, dtype=float32), array(0.7393397, dtype=float32), array(0.5011574, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 28/200 [D loss: 0.7392233610153198, acc.: 50.56716799736023] [G loss: [array(0.74033743, dtype=float32), array(0.74033743, dtype=float32), array(0.5011161, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 29/200 [D loss: 0.7399670481681824, acc.: 50.54730176925659] [G loss: [array(0.74077797, dtype=float32), array(0.74077797, dtype=float32), array(0.5010776, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 30/200 [D loss: 0.7405769228935242, acc.: 50.5287766456604] [G loss: [array(0.74154335, dtype=float32), array(0.74154335, dtype=float32), array(0.50104165, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 31/200 [D loss: 0.7416355013847351, acc.: 50.51146745681763] [G loss: [array(0.7428332, dtype=float32), array(0.7428332, dtype=float32), array(0.5010081, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 32/200 [D loss: 0.7427278161048889, acc.: 50.49525499343872] [G loss: [array(0.7436945, dtype=float32), array(0.7436945, dtype=float32), array(0.50097656, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 33/200 [D loss: 0.7435818314552307, acc.: 50.48004388809204] [G loss: [array(0.74456704, dtype=float32), array(0.74456704, dtype=float32), array(0.500947, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# BENIGN Epoch 34/200 [D loss: 0.7442469596862793, acc.: 50.46572685241699] [G loss: [array(0.744943, dtype=float32), array(0.744943, dtype=float32), array(0.5009191, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# BENIGN Epoch 35/200 [D loss: 0.7446802854537964, acc.: 50.452256202697754] [G loss: [array(0.74548817, dtype=float32), array(0.74548817, dtype=float32), array(0.5008929, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 36/200 [D loss: 0.7451887130737305, acc.: 50.43953061103821] [G loss: [array(0.7459454, dtype=float32), array(0.7459454, dtype=float32), array(0.5008681, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 37/200 [D loss: 0.7458083629608154, acc.: 50.427502393722534] [G loss: [array(0.7466954, dtype=float32), array(0.7466954, dtype=float32), array(0.5008446, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# BENIGN Epoch 38/200 [D loss: 0.7465105056762695, acc.: 50.416117906570435] [G loss: [array(0.74730664, dtype=float32), array(0.74730664, dtype=float32), array(0.50082237, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 39/200 [D loss: 0.7470654845237732, acc.: 50.40532350540161] [G loss: [array(0.74774736, dtype=float32), array(0.74774736, dtype=float32), array(0.50080127, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# BENIGN Epoch 40/200 [D loss: 0.7476767301559448, acc.: 50.395071506500244] [G loss: [array(0.7485455, dtype=float32), array(0.7485455, dtype=float32), array(0.50078124, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 41/200 [D loss: 0.7482945322990417, acc.: 50.385332107543945] [G loss: [array(0.749026, dtype=float32), array(0.749026, dtype=float32), array(0.5007622, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# BENIGN Epoch 42/200 [D loss: 0.7488569617271423, acc.: 50.376057624816895] [G loss: [array(0.74965537, dtype=float32), array(0.74965537, dtype=float32), array(0.50074404, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 43/200 [D loss: 0.7495229244232178, acc.: 50.36722421646118] [G loss: [array(0.7502779, dtype=float32), array(0.7502779, dtype=float32), array(0.50072676, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# BENIGN Epoch 44/200 [D loss: 0.7501801252365112, acc.: 50.358784198760986] [G loss: [array(0.7510195, dtype=float32), array(0.7510195, dtype=float32), array(0.50071025, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 45/200 [D loss: 0.7508615255355835, acc.: 50.35073757171631] [G loss: [array(0.75155896, dtype=float32), array(0.75155896, dtype=float32), array(0.50069445, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 46/200 [D loss: 0.7513746023178101, acc.: 50.34303665161133] [G loss: [array(0.75212896, dtype=float32), array(0.75212896, dtype=float32), array(0.5006794, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 47/200 [D loss: 0.7519416213035583, acc.: 50.33566355705261] [G loss: [array(0.7526462, dtype=float32), array(0.7526462, dtype=float32), array(0.5006649, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 48/200 [D loss: 0.7524917125701904, acc.: 50.328606367111206] [G loss: [array(0.7531852, dtype=float32), array(0.7531852, dtype=float32), array(0.50065106, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 49/200 [D loss: 0.7531391382217407, acc.: 50.3218412399292] [G loss: [array(0.75392425, dtype=float32), array(0.75392425, dtype=float32), array(0.50063777, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 50/200 [D loss: 0.7536656260490417, acc.: 50.31534433364868] [G loss: [array(0.7542419, dtype=float32), array(0.7542419, dtype=float32), array(0.500625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# BENIGN Epoch 51/200 [D loss: 0.754078209400177, acc.: 50.30909776687622] [G loss: [array(0.75472724, dtype=float32), array(0.75472724, dtype=float32), array(0.50061274, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 52/200 [D loss: 0.7546548247337341, acc.: 50.303101539611816] [G loss: [array(0.75535876, dtype=float32), array(0.75535876, dtype=float32), array(0.50060093, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 53/200 [D loss: 0.7551807165145874, acc.: 50.297337770462036] [G loss: [array(0.7557894, dtype=float32), array(0.7557894, dtype=float32), array(0.5005896, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 54/200 [D loss: 0.7556399703025818, acc.: 50.29178857803345] [G loss: [array(0.7562539, dtype=float32), array(0.7562539, dtype=float32), array(0.5005787, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# BENIGN Epoch 55/200 [D loss: 0.756121814250946, acc.: 50.28643608093262] [G loss: [array(0.75673676, dtype=float32), array(0.75673676, dtype=float32), array(0.5005682, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# BENIGN Epoch 56/200 [D loss: 0.756549596786499, acc.: 50.281280279159546] [G loss: [array(0.7571155, dtype=float32), array(0.7571155, dtype=float32), array(0.500558, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# BENIGN Epoch 57/200 [D loss: 0.7569853067398071, acc.: 50.2763032913208] [G loss: [array(0.7576018, dtype=float32), array(0.7576018, dtype=float32), array(0.50054824, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# BENIGN Epoch 58/200 [D loss: 0.7574251890182495, acc.: 50.271499156951904] [G loss: [array(0.7579914, dtype=float32), array(0.7579914, dtype=float32), array(0.50053877, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 59/200 [D loss: 0.7577379941940308, acc.: 50.266867876052856] [G loss: [array(0.75822246, dtype=float32), array(0.75822246, dtype=float32), array(0.50052965, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 60/200 [D loss: 0.7580183744430542, acc.: 50.26238560676575] [G loss: [array(0.758564, dtype=float32), array(0.758564, dtype=float32), array(0.5005208, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 61/200 [D loss: 0.7583665251731873, acc.: 50.258052349090576] [G loss: [array(0.7589116, dtype=float32), array(0.7589116, dtype=float32), array(0.5005123, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# BENIGN Epoch 62/200 [D loss: 0.758787989616394, acc.: 50.25385618209839] [G loss: [array(0.7593644, dtype=float32), array(0.7593644, dtype=float32), array(0.500504, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# BENIGN Epoch 63/200 [D loss: 0.7591828107833862, acc.: 50.24980306625366] [G loss: [array(0.759699, dtype=float32), array(0.759699, dtype=float32), array(0.50049603, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 64/200 [D loss: 0.7595391869544983, acc.: 50.245869159698486] [G loss: [array(0.7600435, dtype=float32), array(0.7600435, dtype=float32), array(0.5004883, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 65/200 [D loss: 0.7598493695259094, acc.: 50.24206042289734] [G loss: [array(0.76035845, dtype=float32), array(0.76035845, dtype=float32), array(0.5004808, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 66/200 [D loss: 0.7601813673973083, acc.: 50.23837089538574] [G loss: [array(0.7606913, dtype=float32), array(0.7606913, dtype=float32), array(0.5004735, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 67/200 [D loss: 0.7605378031730652, acc.: 50.234782695770264] [G loss: [array(0.7610492, dtype=float32), array(0.7610492, dtype=float32), array(0.5004664, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 68/200 [D loss: 0.7609214186668396, acc.: 50.231313705444336] [G loss: [array(0.7614501, dtype=float32), array(0.7614501, dtype=float32), array(0.50045955, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 69/200 [D loss: 0.7613317370414734, acc.: 50.22794008255005] [G loss: [array(0.76185733, dtype=float32), array(0.76185733, dtype=float32), array(0.5004529, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 70/200 [D loss: 0.7617461681365967, acc.: 50.2246618270874] [G loss: [array(0.7622713, dtype=float32), array(0.7622713, dtype=float32), array(0.50044644, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 71/200 [D loss: 0.7620848417282104, acc.: 50.232481956481934] [G loss: [array(0.76252455, dtype=float32), array(0.76252455, dtype=float32), array(0.50066024, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# BENIGN Epoch 72/200 [D loss: 0.7624127864837646, acc.: 50.240159034729004] [G loss: [array(0.76294374, dtype=float32), array(0.76294374, dtype=float32), array(0.50065106, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 73/200 [D loss: 0.7627378106117249, acc.: 50.23684501647949] [G loss: [array(0.7631961, dtype=float32), array(0.7631961, dtype=float32), array(0.5006421, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 74/200 [D loss: 0.7630265951156616, acc.: 50.23362636566162] [G loss: [array(0.76349497, dtype=float32), array(0.76349497, dtype=float32), array(0.5006334, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 75/200 [D loss: 0.763386607170105, acc.: 50.23049712181091] [G loss: [array(0.7639073, dtype=float32), array(0.7639073, dtype=float32), array(0.500625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 76/200 [D loss: 0.7637701034545898, acc.: 50.22744536399841] [G loss: [array(0.764235, dtype=float32), array(0.764235, dtype=float32), array(0.5006168, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 77/200 [D loss: 0.7641159296035767, acc.: 50.22447109222412] [G loss: [array(0.7645812, dtype=float32), array(0.7645812, dtype=float32), array(0.50060874, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 78/200 [D loss: 0.7644636631011963, acc.: 50.221580266952515] [G loss: [array(0.76495403, dtype=float32), array(0.76495403, dtype=float32), array(0.50060093, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 79/200 [D loss: 0.7647789716720581, acc.: 50.21876096725464] [G loss: [array(0.7652123, dtype=float32), array(0.7652123, dtype=float32), array(0.50059336, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 80/200 [D loss: 0.7651364803314209, acc.: 50.216007232666016] [G loss: [array(0.76563156, dtype=float32), array(0.76563156, dtype=float32), array(0.5005859, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 81/200 [D loss: 0.7654480934143066, acc.: 50.21332502365112] [G loss: [array(0.76587415, dtype=float32), array(0.76587415, dtype=float32), array(0.5005787, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 82/200 [D loss: 0.765709400177002, acc.: 50.21071434020996] [G loss: [array(0.7661162, dtype=float32), array(0.7661162, dtype=float32), array(0.50057167, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 83/200 [D loss: 0.7659486532211304, acc.: 50.208163261413574] [G loss: [array(0.7663585, dtype=float32), array(0.7663585, dtype=float32), array(0.50056475, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 84/200 [D loss: 0.7662438154220581, acc.: 50.20567178726196] [G loss: [array(0.7666892, dtype=float32), array(0.7666892, dtype=float32), array(0.500558, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 85/200 [D loss: 0.766532301902771, acc.: 50.20323991775513] [G loss: [array(0.7669408, dtype=float32), array(0.7669408, dtype=float32), array(0.50055146, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# BENIGN Epoch 86/200 [D loss: 0.7668375372886658, acc.: 50.200867652893066] [G loss: [array(0.76726913, dtype=float32), array(0.76726913, dtype=float32), array(0.5005451, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# BENIGN Epoch 87/200 [D loss: 0.7671481966972351, acc.: 50.198543071746826] [G loss: [array(0.76755804, dtype=float32), array(0.76755804, dtype=float32), array(0.50053877, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# BENIGN Epoch 88/200 [D loss: 0.7673865556716919, acc.: 50.19627809524536] [G loss: [array(0.7677988, dtype=float32), array(0.7677988, dtype=float32), array(0.5005327, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# BENIGN Epoch 89/200 [D loss: 0.7676452398300171, acc.: 50.19406080245972] [G loss: [array(0.76804, dtype=float32), array(0.76804, dtype=float32), array(0.50052667, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# BENIGN Epoch 90/200 [D loss: 0.7679422497749329, acc.: 50.19189119338989] [G loss: [array(0.7683722, dtype=float32), array(0.7683722, dtype=float32), array(0.5005208, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 91/200 [D loss: 0.7683133482933044, acc.: 50.189775228500366] [G loss: [array(0.76878536, dtype=float32), array(0.76878536, dtype=float32), array(0.5005151, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 92/200 [D loss: 0.7686387896537781, acc.: 50.18770098686218] [G loss: [array(0.76902896, dtype=float32), array(0.76902896, dtype=float32), array(0.5005095, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 93/200 [D loss: 0.7688513398170471, acc.: 50.18567442893982] [G loss: [array(0.7691873, dtype=float32), array(0.7691873, dtype=float32), array(0.500504, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 94/200 [D loss: 0.7690725922584534, acc.: 50.1836895942688] [G loss: [array(0.7694713, dtype=float32), array(0.7694713, dtype=float32), array(0.50049865, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 95/200 [D loss: 0.7693754434585571, acc.: 50.18174648284912] [G loss: [array(0.76979464, dtype=float32), array(0.76979464, dtype=float32), array(0.5004934, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 96/200 [D loss: 0.7696822881698608, acc.: 50.179845094680786] [G loss: [array(0.77008754, dtype=float32), array(0.77008754, dtype=float32), array(0.5004883, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 97/200 [D loss: 0.7699706554412842, acc.: 50.177985429763794] [G loss: [array(0.77034616, dtype=float32), array(0.77034616, dtype=float32), array(0.5004833, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 98/200 [D loss: 0.7702045440673828, acc.: 50.17615556716919] [G loss: [array(0.77055514, dtype=float32), array(0.77055514, dtype=float32), array(0.5004783, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 99/200 [D loss: 0.7704161405563354, acc.: 50.174373388290405] [G loss: [array(0.77077174, dtype=float32), array(0.77077174, dtype=float32), array(0.5004735, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# BENIGN Epoch 100/200 [D loss: 0.7706643342971802, acc.: 50.17262101173401] [G loss: [array(0.7710455, dtype=float32), array(0.7710455, dtype=float32), array(0.50046873, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 101/200 [D loss: 0.7708852291107178, acc.: 50.17090439796448] [G loss: [array(0.77122587, dtype=float32), array(0.77122587, dtype=float32), array(0.5004641, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 102/200 [D loss: 0.7710636854171753, acc.: 50.169217586517334] [G loss: [array(0.7713948, dtype=float32), array(0.7713948, dtype=float32), array(0.50045955, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 103/200 [D loss: 0.7712613344192505, acc.: 50.16757249832153] [G loss: [array(0.7716165, dtype=float32), array(0.7716165, dtype=float32), array(0.5004551, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 104/200 [D loss: 0.771507978439331, acc.: 50.16595125198364] [G loss: [array(0.7718913, dtype=float32), array(0.7718913, dtype=float32), array(0.50045073, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 105/200 [D loss: 0.7717592120170593, acc.: 50.16436576843262] [G loss: [array(0.77210647, dtype=float32), array(0.77210647, dtype=float32), array(0.50044644, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 106/200 [D loss: 0.7720259428024292, acc.: 50.16281008720398] [G loss: [array(0.7724041, dtype=float32), array(0.7724041, dtype=float32), array(0.5004422, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 107/200 [D loss: 0.772292971611023, acc.: 50.16127824783325] [G loss: [array(0.7726392, dtype=float32), array(0.7726392, dtype=float32), array(0.5004381, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# BENIGN Epoch 108/200 [D loss: 0.7725275158882141, acc.: 50.15978217124939] [G loss: [array(0.7728721, dtype=float32), array(0.7728721, dtype=float32), array(0.50043404, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 109/200 [D loss: 0.7727262377738953, acc.: 50.15830993652344] [G loss: [array(0.773063, dtype=float32), array(0.773063, dtype=float32), array(0.50043005, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 110/200 [D loss: 0.772952139377594, acc.: 50.15686750411987] [G loss: [array(0.77329576, dtype=float32), array(0.77329576, dtype=float32), array(0.5004261, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 111/200 [D loss: 0.7731932401657104, acc.: 50.15544891357422] [G loss: [array(0.7735399, dtype=float32), array(0.7735399, dtype=float32), array(0.5004223, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 112/200 [D loss: 0.7734403610229492, acc.: 50.154054164886475] [G loss: [array(0.7737899, dtype=float32), array(0.7737899, dtype=float32), array(0.50041854, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 113/200 [D loss: 0.7736876010894775, acc.: 50.15268325805664] [G loss: [array(0.77402055, dtype=float32), array(0.77402055, dtype=float32), array(0.50041485, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 114/200 [D loss: 0.7738714218139648, acc.: 50.151342153549194] [G loss: [array(0.77417886, dtype=float32), array(0.77417886, dtype=float32), array(0.5004112, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 115/200 [D loss: 0.7740383148193359, acc.: 50.15002489089966] [G loss: [array(0.7743529, dtype=float32), array(0.7743529, dtype=float32), array(0.50040764, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 116/200 [D loss: 0.7742048501968384, acc.: 50.148725509643555] [G loss: [array(0.7745017, dtype=float32), array(0.7745017, dtype=float32), array(0.5004041, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 117/200 [D loss: 0.7743408679962158, acc.: 50.14744997024536] [G loss: [array(0.7746331, dtype=float32), array(0.7746331, dtype=float32), array(0.50040066, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# BENIGN Epoch 118/200 [D loss: 0.7745273113250732, acc.: 50.1461923122406] [G loss: [array(0.77484846, dtype=float32), array(0.77484846, dtype=float32), array(0.50039726, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 119/200 [D loss: 0.7747052907943726, acc.: 50.14495849609375] [G loss: [array(0.7749913, dtype=float32), array(0.7749913, dtype=float32), array(0.5003939, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 120/200 [D loss: 0.7748544812202454, acc.: 50.14374852180481] [G loss: [array(0.7751518, dtype=float32), array(0.7751518, dtype=float32), array(0.50039065, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# BENIGN Epoch 121/200 [D loss: 0.7750005722045898, acc.: 50.142550468444824] [G loss: [array(0.775286, dtype=float32), array(0.775286, dtype=float32), array(0.5003874, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 122/200 [D loss: 0.7751495838165283, acc.: 50.14138221740723] [G loss: [array(0.7754397, dtype=float32), array(0.7754397, dtype=float32), array(0.5003842, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 123/200 [D loss: 0.775288462638855, acc.: 50.140225887298584] [G loss: [array(0.7755553, dtype=float32), array(0.7755553, dtype=float32), array(0.5003811, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# BENIGN Epoch 124/200 [D loss: 0.7754140496253967, acc.: 50.13909339904785] [G loss: [array(0.77569664, dtype=float32), array(0.77569664, dtype=float32), array(0.500378, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 125/200 [D loss: 0.775551974773407, acc.: 50.137972831726074] [G loss: [array(0.77583957, dtype=float32), array(0.77583957, dtype=float32), array(0.500375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# BENIGN Epoch 126/200 [D loss: 0.7757360935211182, acc.: 50.13687610626221] [G loss: [array(0.77605075, dtype=float32), array(0.77605075, dtype=float32), array(0.50037205, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# BENIGN Epoch 127/200 [D loss: 0.7759745717048645, acc.: 50.135791301727295] [G loss: [array(0.7763132, dtype=float32), array(0.7763132, dtype=float32), array(0.5003691, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# BENIGN Epoch 128/200 [D loss: 0.7761783599853516, acc.: 50.13473033905029] [G loss: [array(0.77645755, dtype=float32), array(0.77645755, dtype=float32), array(0.5003662, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# BENIGN Epoch 129/200 [D loss: 0.7763373851776123, acc.: 50.133681297302246] [G loss: [array(0.7766262, dtype=float32), array(0.7766262, dtype=float32), array(0.50036335, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# BENIGN Epoch 130/200 [D loss: 0.776456892490387, acc.: 50.13265013694763] [G loss: [array(0.77668774, dtype=float32), array(0.77668774, dtype=float32), array(0.50036055, dtype=float32)]]
# Training stopped early due to insignificant loss improvement at epoch 130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# DDoS Epoch 1/200 [D loss: 0.7094849348068237, acc.: 10.9375] [G loss: [array(0.7045658, dtype=float32), array(0.7045658, dtype=float32), array(0.21875, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# DDoS Epoch 2/200 [D loss: 0.7061905264854431, acc.: 16.66666567325592] [G loss: [array(0.70551556, dtype=float32), array(0.70551556, dtype=float32), array(0.1875, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 3/200 [D loss: 0.7067969441413879, acc.: 16.614583134651184] [G loss: [array(0.70644945, dtype=float32), array(0.70644945, dtype=float32), array(0.18229167, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 4/200 [D loss: 0.7083195447921753, acc.: 15.625] [G loss: [array(0.7088203, dtype=float32), array(0.7088203, dtype=float32), array(0.15625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# DDoS Epoch 5/200 [D loss: 0.7097591161727905, acc.: 14.131945371627808] [G loss: [array(0.7101668, dtype=float32), array(0.7101668, dtype=float32), array(0.14375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 6/200 [D loss: 0.7102791666984558, acc.: 13.825756311416626] [G loss: [array(0.7099059, dtype=float32), array(0.7099059, dtype=float32), array(0.14583333, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# DDoS Epoch 7/200 [D loss: 0.7106939554214478, acc.: 13.315591216087341] [G loss: [array(0.7112946, dtype=float32), array(0.7112946, dtype=float32), array(0.13169643, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 8/200 [D loss: 0.711698055267334, acc.: 13.18359375] [G loss: [array(0.71194273, dtype=float32), array(0.71194273, dtype=float32), array(0.13867188, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 9/200 [D loss: 0.7122998237609863, acc.: 13.296568393707275] [G loss: [array(0.7125995, dtype=float32), array(0.7125995, dtype=float32), array(0.13541667, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 10/200 [D loss: 0.7130599021911621, acc.: 13.055098056793213] [G loss: [array(0.71340346, dtype=float32), array(0.71340346, dtype=float32), array(0.1328125, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# DDoS Epoch 11/200 [D loss: 0.7138949632644653, acc.: 12.929517030715942] [G loss: [array(0.71433246, dtype=float32), array(0.71433246, dtype=float32), array(0.13210227, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# DDoS Epoch 12/200 [D loss: 0.7146608829498291, acc.: 12.763246893882751] [G loss: [array(0.71498513, dtype=float32), array(0.71498513, dtype=float32), array(0.12890625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# DDoS Epoch 13/200 [D loss: 0.71526700258255, acc.: 12.377403676509857] [G loss: [array(0.7155624, dtype=float32), array(0.7155624, dtype=float32), array(0.12379808, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# DDoS Epoch 14/200 [D loss: 0.7158679366111755, acc.: 11.987434327602386] [G loss: [array(0.7162182, dtype=float32), array(0.7162182, dtype=float32), array(0.12053572, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 15/200 [D loss: 0.7164667248725891, acc.: 11.808548867702484] [G loss: [array(0.71685874, dtype=float32), array(0.71685874, dtype=float32), array(0.11979166, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 16/200 [D loss: 0.717151939868927, acc.: 11.606918275356293] [G loss: [array(0.7175644, dtype=float32), array(0.7175644, dtype=float32), array(0.11621094, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 17/200 [D loss: 0.7178082466125488, acc.: 11.332999169826508] [G loss: [array(0.7181689, dtype=float32), array(0.7181689, dtype=float32), array(0.11397059, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 18/200 [D loss: 0.7185801267623901, acc.: 10.961061716079712] [G loss: [array(0.71913433, dtype=float32), array(0.71913433, dtype=float32), array(0.10850695, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 19/200 [D loss: 0.719404935836792, acc.: 10.541874170303345] [G loss: [array(0.71982205, dtype=float32), array(0.71982205, dtype=float32), array(0.10526316, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# DDoS Epoch 20/200 [D loss: 0.7201870679855347, acc.: 10.167267918586731] [G loss: [array(0.72069734, dtype=float32), array(0.72069734, dtype=float32), array(0.10078125, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# DDoS Epoch 21/200 [D loss: 0.720975399017334, acc.: 9.752468764781952] [G loss: [array(0.7213886, dtype=float32), array(0.7213886, dtype=float32), array(0.09672619, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# DDoS Epoch 22/200 [D loss: 0.7217294573783875, acc.: 9.411337226629257] [G loss: [array(0.722247, dtype=float32), array(0.722247, dtype=float32), array(0.09375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# DDoS Epoch 23/200 [D loss: 0.7223364114761353, acc.: 9.236866235733032] [G loss: [array(0.72261983, dtype=float32), array(0.72261983, dtype=float32), array(0.09307065, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# DDoS Epoch 24/200 [D loss: 0.7229942083358765, acc.: 9.046708792448044] [G loss: [array(0.7235296, dtype=float32), array(0.7235296, dtype=float32), array(0.08984375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# DDoS Epoch 25/200 [D loss: 0.7235881090164185, acc.: 8.806760609149933] [G loss: [array(0.7238511, dtype=float32), array(0.7238511, dtype=float32), array(0.088125, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 26/200 [D loss: 0.7238761782646179, acc.: 8.736920356750488] [G loss: [array(0.72412384, dtype=float32), array(0.72412384, dtype=float32), array(0.08834135, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 27/200 [D loss: 0.7242555022239685, acc.: 8.731874823570251] [G loss: [array(0.7246163, dtype=float32), array(0.7246163, dtype=float32), array(0.08796296, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 28/200 [D loss: 0.7248609066009521, acc.: 8.615057170391083] [G loss: [array(0.7253057, dtype=float32), array(0.7253057, dtype=float32), array(0.0859375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 29/200 [D loss: 0.7253854274749756, acc.: 8.451016992330551] [G loss: [array(0.7256438, dtype=float32), array(0.7256438, dtype=float32), array(0.08459052, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 30/200 [D loss: 0.725845456123352, acc.: 8.272422850131989] [G loss: [array(0.7262131, dtype=float32), array(0.7262131, dtype=float32), array(0.08229167, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# DDoS Epoch 31/200 [D loss: 0.7263926267623901, acc.: 8.028985559940338] [G loss: [array(0.72679186, dtype=float32), array(0.72679186, dtype=float32), array(0.0796371, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 32/200 [D loss: 0.7267478704452515, acc.: 7.94697105884552] [G loss: [array(0.7269229, dtype=float32), array(0.7269229, dtype=float32), array(0.08056641, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 33/200 [D loss: 0.727046549320221, acc.: 7.9199448227882385] [G loss: [array(0.72737813, dtype=float32), array(0.72737813, dtype=float32), array(0.07907197, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 34/200 [D loss: 0.727454662322998, acc.: 7.823817431926727] [G loss: [array(0.72770137, dtype=float32), array(0.72770137, dtype=float32), array(0.07858456, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 35/200 [D loss: 0.7278465032577515, acc.: 7.711568474769592] [G loss: [array(0.7281771, dtype=float32), array(0.7281771, dtype=float32), array(0.07678571, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 36/200 [D loss: 0.7282471656799316, acc.: 7.539550960063934] [G loss: [array(0.72851944, dtype=float32), array(0.72851944, dtype=float32), array(0.0750868, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 37/200 [D loss: 0.7286953926086426, acc.: 7.37689733505249] [G loss: [array(0.72905207, dtype=float32), array(0.72905207, dtype=float32), array(0.07347973, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 38/200 [D loss: 0.7291892766952515, acc.: 7.284539192914963] [G loss: [array(0.72952086, dtype=float32), array(0.72952086, dtype=float32), array(0.07319079, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 39/200 [D loss: 0.729656994342804, acc.: 7.197750359773636] [G loss: [array(0.73000705, dtype=float32), array(0.73000705, dtype=float32), array(0.07171474, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# DDoS Epoch 40/200 [D loss: 0.7300865650177002, acc.: 7.055973261594772] [G loss: [array(0.7303838, dtype=float32), array(0.7303838, dtype=float32), array(0.0703125, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 41/200 [D loss: 0.7305091619491577, acc.: 6.921155750751495] [G loss: [array(0.73082346, dtype=float32), array(0.73082346, dtype=float32), array(0.06897866, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 42/200 [D loss: 0.7308881282806396, acc.: 6.811397522687912] [G loss: [array(0.73115444, dtype=float32), array(0.73115444, dtype=float32), array(0.06808036, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 43/200 [D loss: 0.7312360405921936, acc.: 6.706994026899338] [G loss: [array(0.73150605, dtype=float32), array(0.73150605, dtype=float32), array(0.06686047, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 44/200 [D loss: 0.7316104173660278, acc.: 6.607154011726379] [G loss: [array(0.73191243, dtype=float32), array(0.73191243, dtype=float32), array(0.06605113, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 45/200 [D loss: 0.7319492697715759, acc.: 6.494615972042084] [G loss: [array(0.7322029, dtype=float32), array(0.7322029, dtype=float32), array(0.06458333, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 46/200 [D loss: 0.73232501745224, acc.: 6.386616080999374] [G loss: [array(0.7326241, dtype=float32), array(0.7326241, dtype=float32), array(0.0638587, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 47/200 [D loss: 0.7327052354812622, acc.: 6.2836021184921265] [G loss: [array(0.73299134, dtype=float32), array(0.73299134, dtype=float32), array(0.0625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 48/200 [D loss: 0.7330028414726257, acc.: 6.184553354978561] [G loss: [array(0.73323256, dtype=float32), array(0.73323256, dtype=float32), array(0.06184896, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 49/200 [D loss: 0.7334084510803223, acc.: 6.121791526675224] [G loss: [array(0.7337468, dtype=float32), array(0.7337468, dtype=float32), array(0.06122449, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 50/200 [D loss: 0.7338319420814514, acc.: 6.045927852392197] [G loss: [array(0.73411417, dtype=float32), array(0.73411417, dtype=float32), array(0.0603125, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 51/200 [D loss: 0.7341468334197998, acc.: 5.942262336611748] [G loss: [array(0.73439324, dtype=float32), array(0.73439324, dtype=float32), array(0.0591299, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# DDoS Epoch 52/200 [D loss: 0.7345336675643921, acc.: 5.827430635690689] [G loss: [array(0.73487324, dtype=float32), array(0.73487324, dtype=float32), array(0.05799279, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# DDoS Epoch 53/200 [D loss: 0.73494553565979, acc.: 5.716953054070473] [G loss: [array(0.7352133, dtype=float32), array(0.7352133, dtype=float32), array(0.05689859, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 54/200 [D loss: 0.7352524995803833, acc.: 5.625054240226746] [G loss: [array(0.7354791, dtype=float32), array(0.7354791, dtype=float32), array(0.05613426, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 55/200 [D loss: 0.7355519533157349, acc.: 5.550849437713623] [G loss: [array(0.7358204, dtype=float32), array(0.7358204, dtype=float32), array(0.05539773, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 56/200 [D loss: 0.7359073758125305, acc.: 5.479307472705841] [G loss: [array(0.73618764, dtype=float32), array(0.73618764, dtype=float32), array(0.0546875, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 57/200 [D loss: 0.7362685203552246, acc.: 5.423992872238159] [G loss: [array(0.7365499, dtype=float32), array(0.7365499, dtype=float32), array(0.05427632, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 58/200 [D loss: 0.7365976572036743, acc.: 5.357243120670319] [G loss: [array(0.73683757, dtype=float32), array(0.73683757, dtype=float32), array(0.05334052, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 59/200 [D loss: 0.736914873123169, acc.: 5.279294401407242] [G loss: [array(0.73718566, dtype=float32), array(0.73718566, dtype=float32), array(0.05270127, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 60/200 [D loss: 0.737209141254425, acc.: 5.217086523771286] [G loss: [array(0.73741853, dtype=float32), array(0.73741853, dtype=float32), array(0.05208333, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# DDoS Epoch 61/200 [D loss: 0.7375003099441528, acc.: 5.144120007753372] [G loss: [array(0.73778105, dtype=float32), array(0.73778105, dtype=float32), array(0.05122951, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 62/200 [D loss: 0.737842857837677, acc.: 5.060811713337898] [G loss: [array(0.73810744, dtype=float32), array(0.73810744, dtype=float32), array(0.05040323, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 63/200 [D loss: 0.7380934357643127, acc.: 5.004960298538208] [G loss: [array(0.73827153, dtype=float32), array(0.73827153, dtype=float32), array(0.05009921, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 64/200 [D loss: 0.7383347749710083, acc.: 4.951056465506554] [G loss: [array(0.73858976, dtype=float32), array(0.73858976, dtype=float32), array(0.04931641, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 65/200 [D loss: 0.7386114597320557, acc.: 4.886609315872192] [G loss: [array(0.7388244, dtype=float32), array(0.7388244, dtype=float32), array(0.04879808, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 66/200 [D loss: 0.7388625144958496, acc.: 4.836051166057587] [G loss: [array(0.7390902, dtype=float32), array(0.7390902, dtype=float32), array(0.04829545, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 67/200 [D loss: 0.7391482591629028, acc.: 4.787008464336395] [G loss: [array(0.7394094, dtype=float32), array(0.7394094, dtype=float32), array(0.04780784, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# DDoS Epoch 68/200 [D loss: 0.7394261360168457, acc.: 4.7279242426157] [G loss: [array(0.7396277, dtype=float32), array(0.7396277, dtype=float32), array(0.04710478, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 69/200 [D loss: 0.7396879196166992, acc.: 4.670475050806999] [G loss: [array(0.7399385, dtype=float32), array(0.7399385, dtype=float32), array(0.04664855, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 70/200 [D loss: 0.7399348020553589, acc.: 4.625915363430977] [G loss: [array(0.74012214, dtype=float32), array(0.74012214, dtype=float32), array(0.04620536, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 71/200 [D loss: 0.7401494979858398, acc.: 4.5826151967048645] [G loss: [array(0.74036586, dtype=float32), array(0.74036586, dtype=float32), array(0.04577465, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 72/200 [D loss: 0.7404358386993408, acc.: 4.529671743512154] [G loss: [array(0.7406995, dtype=float32), array(0.7406995, dtype=float32), array(0.04513889, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 73/200 [D loss: 0.7406768202781677, acc.: 4.478108882904053] [G loss: [array(0.74085623, dtype=float32), array(0.74085623, dtype=float32), array(0.04473459, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 74/200 [D loss: 0.740882396697998, acc.: 4.4385746121406555] [G loss: [array(0.74109876, dtype=float32), array(0.74109876, dtype=float32), array(0.04434122, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 75/200 [D loss: 0.741132915019989, acc.: 4.389680922031403] [G loss: [array(0.7413645, dtype=float32), array(0.7413645, dtype=float32), array(0.04375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# DDoS Epoch 76/200 [D loss: 0.7414448261260986, acc.: 4.331730306148529] [G loss: [array(0.741705, dtype=float32), array(0.741705, dtype=float32), array(0.04317434, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 77/200 [D loss: 0.741759717464447, acc.: 4.275289922952652] [G loss: [array(0.7419982, dtype=float32), array(0.7419982, dtype=float32), array(0.04261364, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 78/200 [D loss: 0.7420477867126465, acc.: 4.2303167283535] [G loss: [array(0.7422781, dtype=float32), array(0.7422781, dtype=float32), array(0.04226763, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 79/200 [D loss: 0.7423322200775146, acc.: 4.196439683437347] [G loss: [array(0.7425711, dtype=float32), array(0.7425711, dtype=float32), array(0.04193038, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 80/200 [D loss: 0.7425960302352905, acc.: 4.153645783662796] [G loss: [array(0.7428122, dtype=float32), array(0.7428122, dtype=float32), array(0.04140625, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 81/200 [D loss: 0.7428512573242188, acc.: 4.102206602692604] [G loss: [array(0.7430701, dtype=float32), array(0.7430701, dtype=float32), array(0.04089506, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# DDoS Epoch 82/200 [D loss: 0.7431255578994751, acc.: 4.0520258247852325] [G loss: [array(0.7433579, dtype=float32), array(0.7433579, dtype=float32), array(0.04039634, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 83/200 [D loss: 0.7433943748474121, acc.: 4.012470319867134] [G loss: [array(0.74361384, dtype=float32), array(0.74361384, dtype=float32), array(0.04009789, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# DDoS Epoch 84/200 [D loss: 0.7436299324035645, acc.: 3.973916172981262] [G loss: [array(0.74382067, dtype=float32), array(0.74382067, dtype=float32), array(0.03962054, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 85/200 [D loss: 0.7438293695449829, acc.: 3.9270251989364624] [G loss: [array(0.74402684, dtype=float32), array(0.74402684, dtype=float32), array(0.03915441, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 86/200 [D loss: 0.7440515160560608, acc.: 3.8903124630451202] [G loss: [array(0.7442476, dtype=float32), array(0.7442476, dtype=float32), array(0.03888081, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 87/200 [D loss: 0.7442833185195923, acc.: 3.854499012231827] [G loss: [array(0.7444934, dtype=float32), array(0.7444934, dtype=float32), array(0.03843391, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# DDoS Epoch 88/200 [D loss: 0.7445499897003174, acc.: 3.810572251677513] [G loss: [array(0.7447795, dtype=float32), array(0.7447795, dtype=float32), array(0.03799716, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 89/200 [D loss: 0.744792103767395, acc.: 3.7676356732845306] [G loss: [array(0.74498945, dtype=float32), array(0.74498945, dtype=float32), array(0.03757022, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 90/200 [D loss: 0.7450087070465088, acc.: 3.7343360483646393] [G loss: [array(0.7451824, dtype=float32), array(0.7451824, dtype=float32), array(0.03732639, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# DDoS Epoch 91/200 [D loss: 0.7452136278152466, acc.: 3.7104040384292603] [G loss: [array(0.74542564, dtype=float32), array(0.74542564, dtype=float32), array(0.03708791, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 92/200 [D loss: 0.7454615831375122, acc.: 3.686993569135666] [G loss: [array(0.7456642, dtype=float32), array(0.7456642, dtype=float32), array(0.03685462, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 93/200 [D loss: 0.7456910610198975, acc.: 3.6556869745254517] [G loss: [array(0.74589145, dtype=float32), array(0.74589145, dtype=float32), array(0.03645833, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 94/200 [D loss: 0.7459226846694946, acc.: 3.6166921257972717] [G loss: [array(0.74612385, dtype=float32), array(0.74612385, dtype=float32), array(0.03607048, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 95/200 [D loss: 0.7461224794387817, acc.: 3.5867445170879364] [G loss: [array(0.74629563, dtype=float32), array(0.74629563, dtype=float32), array(0.03585526, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 96/200 [D loss: 0.7463192939758301, acc.: 3.557465225458145] [G loss: [array(0.74651337, dtype=float32), array(0.74651337, dtype=float32), array(0.03548177, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 97/200 [D loss: 0.7465275526046753, acc.: 3.5287491977214813] [G loss: [array(0.7467049, dtype=float32), array(0.7467049, dtype=float32), array(0.03527706, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 98/200 [D loss: 0.7467091083526611, acc.: 3.500661998987198] [G loss: [array(0.7468848, dtype=float32), array(0.7468848, dtype=float32), array(0.03491709, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 99/200 [D loss: 0.7469218373298645, acc.: 3.4652121365070343] [G loss: [array(0.7471245, dtype=float32), array(0.7471245, dtype=float32), array(0.03456439, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 100/200 [D loss: 0.7471503615379333, acc.: 3.438284993171692] [G loss: [array(0.7473465, dtype=float32), array(0.7473465, dtype=float32), array(0.034375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# DDoS Epoch 101/200 [D loss: 0.7473404407501221, acc.: 3.4119315445423126] [G loss: [array(0.74751025, dtype=float32), array(0.74751025, dtype=float32), array(0.03403465, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 102/200 [D loss: 0.7475475072860718, acc.: 3.3783987164497375] [G loss: [array(0.7477458, dtype=float32), array(0.7477458, dtype=float32), array(0.03370098, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 103/200 [D loss: 0.7477446794509888, acc.: 3.345518559217453] [G loss: [array(0.74792325, dtype=float32), array(0.74792325, dtype=float32), array(0.03337379, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# DDoS Epoch 104/200 [D loss: 0.7479070425033569, acc.: 3.3282965421676636] [G loss: [array(0.7480574, dtype=float32), array(0.7480574, dtype=float32), array(0.03335337, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 105/200 [D loss: 0.7480688095092773, acc.: 3.311474621295929] [G loss: [array(0.74825346, dtype=float32), array(0.74825346, dtype=float32), array(0.03303571, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 106/200 [D loss: 0.7482635974884033, acc.: 3.280160203576088] [G loss: [array(0.74843496, dtype=float32), array(0.74843496, dtype=float32), array(0.03272406, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 107/200 [D loss: 0.7484390735626221, acc.: 3.25673371553421] [G loss: [array(0.7486031, dtype=float32), array(0.7486031, dtype=float32), array(0.03256425, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 108/200 [D loss: 0.7485997676849365, acc.: 3.233776241540909] [G loss: [array(0.7487602, dtype=float32), array(0.7487602, dtype=float32), array(0.03226273, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# DDoS Epoch 109/200 [D loss: 0.7487812042236328, acc.: 3.211207315325737] [G loss: [array(0.74896336, dtype=float32), array(0.74896336, dtype=float32), array(0.03211009, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 110/200 [D loss: 0.7489625215530396, acc.: 3.1961850821971893] [G loss: [array(0.7491223, dtype=float32), array(0.7491223, dtype=float32), array(0.03196023, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 111/200 [D loss: 0.7491612434387207, acc.: 3.1743954867124557] [G loss: [array(0.7493503, dtype=float32), array(0.7493503, dtype=float32), array(0.0316723, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# DDoS Epoch 112/200 [D loss: 0.7493641376495361, acc.: 3.145989030599594] [G loss: [array(0.74954, dtype=float32), array(0.74954, dtype=float32), array(0.03138951, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 113/200 [D loss: 0.749577522277832, acc.: 3.1180862337350845] [G loss: [array(0.7497759, dtype=float32), array(0.7497759, dtype=float32), array(0.03111173, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# DDoS Epoch 114/200 [D loss: 0.7497987747192383, acc.: 3.0906742438673973] [G loss: [array(0.7499794, dtype=float32), array(0.7499794, dtype=float32), array(0.03083882, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# DDoS Epoch 115/200 [D loss: 0.7499849796295166, acc.: 3.070533461868763] [G loss: [array(0.75014573, dtype=float32), array(0.75014573, dtype=float32), array(0.03070652, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# DDoS Epoch 116/200 [D loss: 0.7501773834228516, acc.: 3.0507702380418777] [G loss: [array(0.7503737, dtype=float32), array(0.7503737, dtype=float32), array(0.03044181, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 117/200 [D loss: 0.7503854632377625, acc.: 3.0246391892433167] [G loss: [array(0.75055605, dtype=float32), array(0.75055605, dtype=float32), array(0.03018162, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# DDoS Epoch 118/200 [D loss: 0.7505829334259033, acc.: 2.9989518225193024] [G loss: [array(0.750768, dtype=float32), array(0.750768, dtype=float32), array(0.02992585, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 119/200 [D loss: 0.7507628202438354, acc.: 2.9736973345279694] [G loss: [array(0.75090784, dtype=float32), array(0.75090784, dtype=float32), array(0.02967437, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# DDoS Epoch 120/200 [D loss: 0.7509071230888367, acc.: 2.9488645493984222] [G loss: [array(0.7510574, dtype=float32), array(0.7510574, dtype=float32), array(0.02942708, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# DDoS Epoch 121/200 [D loss: 0.7510570883750916, acc.: 2.9244432225823402] [G loss: [array(0.751213, dtype=float32), array(0.751213, dtype=float32), array(0.02918389, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 122/200 [D loss: 0.7512201070785522, acc.: 2.9004229232668877] [G loss: [array(0.7513767, dtype=float32), array(0.7513767, dtype=float32), array(0.02894467, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 123/200 [D loss: 0.7513569593429565, acc.: 2.883145585656166] [G loss: [array(0.75149846, dtype=float32), array(0.75149846, dtype=float32), array(0.02883638, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# DDoS Epoch 124/200 [D loss: 0.751479983329773, acc.: 2.8724737465381622] [G loss: [array(0.751606, dtype=float32), array(0.751606, dtype=float32), array(0.02872984, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# DDoS Epoch 125/200 [D loss: 0.7516133785247803, acc.: 2.8557229787111282] [G loss: [array(0.7517701, dtype=float32), array(0.7517701, dtype=float32), array(0.0285, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 126/200 [D loss: 0.7517505884170532, acc.: 2.8330132365226746] [G loss: [array(0.75187725, dtype=float32), array(0.75187725, dtype=float32), array(0.02827381, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# DDoS Epoch 127/200 [D loss: 0.751883864402771, acc.: 2.810661867260933] [G loss: [array(0.7520369, dtype=float32), array(0.7520369, dtype=float32), array(0.02805118, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# DDoS Epoch 128/200 [D loss: 0.7520481944084167, acc.: 2.794763818383217] [G loss: [array(0.7522164, dtype=float32), array(0.7522164, dtype=float32), array(0.0279541, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# DDoS Epoch 129/200 [D loss: 0.7522172927856445, acc.: 2.779136598110199] [G loss: [array(0.7523647, dtype=float32), array(0.7523647, dtype=float32), array(0.0277374, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# DDoS Epoch 130/200 [D loss: 0.7523465752601624, acc.: 2.7577172964811325] [G loss: [array(0.7524736, dtype=float32), array(0.7524736, dtype=float32), array(0.02752404, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# DDoS Epoch 131/200 [D loss: 0.752440333366394, acc.: 2.7425892651081085] [G loss: [array(0.7525587, dtype=float32), array(0.7525587, dtype=float32), array(0.02743321, dtype=float32)]]
# Training stopped early due to insignificant loss improvement at epoch 131
